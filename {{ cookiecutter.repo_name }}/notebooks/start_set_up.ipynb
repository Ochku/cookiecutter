# %%
from pathlib import Path
import sys

# Navigate up from the notebook to the project root
project_root = Path().resolve().parents[0]  # Go one level up: /notebooks -> /project_root
module_dir = project_root / "{{ cookiecutter.module_name }}"

# Add the module directory to Python path so we can import normally
sys.path.insert(0, str(module_dir))

# Now you can import the settings directly
from config import settings

# Standard import for db_utils
import db_utils as utils

# Auto reloader for packages
# %load_ext autoreload
# %autoreload 2

# Example usage of settings
print(f"Data directory: {settings.data_dir}")
print(f"Raw data directory: {settings.raw_dir}")
print(f"Processed data directory: {settings.processed_dir}")
print(f"Output directory: {settings.output_dir}")
